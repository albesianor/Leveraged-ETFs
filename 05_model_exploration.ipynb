# %% [markdown]
# # 5 - Model exploration
# In this notebook we perform a more detailed preliminary exploration of several models to predict portfolio volatility from $\sigma$ and holding horizon. The proposed models are:
# - quadratic regression
# - quadratic regression with weighted least squares
# - quartic regression with fixing coefficients to have 0 at the boundary (doesn't address heteroskedasticity): $(ax + bx^2)(cy + dy^2)$
# - fit log(1 + std)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error

from simulation import lev_sigma_mean_std

# %%
for i in range(1, 6):
    df = lev_sigma_mean_std()
    df.to_csv(f"output/lev_sigma_std_{i}.csv")

# %% [markdown]
# Quadratic regression:

# %%
df = pd.read_csv("output/lev_sigma_std.csv")

# %%
X = df[["leverage", "sigma"]]
z = df["std"]

model = Pipeline(
    [("poly", PolynomialFeatures(degree=2)), ("linear", LinearRegression())]
)
model.fit(X, z)

df["std_fitted"] = model.predict(X)

# %%
print(f"mse = {mean_squared_error(z,df["std_fitted"])}")
# Out:
# mse = 2.3769680095823204e-07

# %%
z.var()
# Out:
# np.float64(0.0014532594566834995)

# %%
model.score(X, z)
# Out:
# 0.9998364224833203

# %% [markdown]
# Transform by log(1+x):

# %%
df = pd.read_csv("output/lev_sigma_std.csv")

# %%
df["log1_std"] = np.log(1 + df["std"])

# %%
# plot

# reshape into matrix form
pivot = df.pivot(index="sigma", columns="leverage", values="log1_std")

X = pivot.columns.values  # leverage values
Y = pivot.index.values  # sigma values
Z = pivot.values  # std values

X, Y = np.meshgrid(X, Y)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection="3d")

ax.plot_surface(X, Y, Z)

ax.set_xlabel("leverage")
ax.set_ylabel("sigma")
ax.set_zlabel("log(1+std)")

plt.show()

# %%
# df has columns ['leverage', 'sigma', 'std']
X = df[["leverage", "sigma"]]
z = df["log1_std"]

model = Pipeline(
    [
        ("poly", PolynomialFeatures(degree=2)),
        ("linear", LinearRegression(fit_intercept=False)),
    ]
)

model.fit(X, z)

df["log1_std_fitted"] = model.predict(X)

# %%
print(f"mse = {mean_squared_error(z,df["log1_std_fitted"])}")
# Out:
# mse = 2.532463110295144e-07

# %%
# access the coefficients
coefficients = model.named_steps["linear"].coef_
intercept = model.named_steps["linear"].intercept_

# get the feature names in the correct order
feature_names = model.named_steps["poly"].get_feature_names_out()

# display coefficients with their corresponding feature names
coef_df = pd.DataFrame({"Feature": feature_names, "Coefficient": coefficients})
print(coef_df)
print(f"Intercept: {intercept}")
# Out:
#           Feature  Coefficient
# 0               1    -0.004717
# 1        leverage     0.004292
# 2           sigma    -0.125129
# 3      leverage^2    -0.000877
# 4  leverage sigma     0.132303
# 5         sigma^2    -0.006951
# Intercept: 0.0

# %% [markdown]
# Note how the coefficients alongside $\sigma$ and $L\sigma$ are close (and of opposite sign). This leads us to consider whether $(L-1)\sigma$ might be the salient feature here. We discuss this further in the `model selection` notebook.

# %%
z.var()  # baseline to compare mse to
# Out:
# np.float64(0.0012909507256444377)

# %%
model.score(X, z)  # R2
# Out:
# 0.9998038099881257

# %%
# compare on original scale

df["std_fitted"] = np.exp(df["log1_std_fitted"]) - 1

print("original-scale mse = ", mean_squared_error(df["std"], df["std_fitted"]))

r2_original_scale = (
    1
    - ((df["std"] - df["std_fitted"]) ** 2).sum()
    / ((df["std"] - df["std"].mean()) ** 2).sum()
)
print("original-scale R^2 = ", r2_original_scale)
# Out:
# original-scale mse =  2.998661575609386e-07
# original-scale R^2 =  0.9997936389501568

# %% [markdown]
# Now address the growing residuals:

# %%
df["residual"] = df["std"] - df["std_fitted"]

# %%
# plot

# reshape into matrix form
pivot = df.pivot(index="sigma", columns="leverage", values="residual")

X = pivot.columns.values  # leverage values
Y = pivot.index.values  # sigma values
R = pivot.values  # residual values

X, Y = np.meshgrid(X, Y)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection="3d")

ax.plot_surface(X, Y, R)

ax.set_xlabel("leverage")
ax.set_ylabel("sigma")
ax.set_zlabel("residuals")

plt.show()

# %%
df["residual_transformed"] = np.log(1 + (df["std"] - df["std_fitted"]) ** 2)

# %%
# reshape into matrix form
pivot = df.pivot(index="sigma", columns="leverage", values="residual_transformed")

X = pivot.columns.values  # leverage values
Y = pivot.index.values  # sigma values
R = pivot.values  # transformed residual values

X, Y = np.meshgrid(X, Y)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection="3d")

ax.plot_surface(X, Y, R)

ax.set_xlabel("leverage")
ax.set_ylabel("sigma")
ax.set_zlabel("log(1+residual^2)")

plt.show()

# %% [markdown]
# Weighted least squares:

# %%
# define weights as exponential in both inputs
# can tune alpha and beta to match how fast residuals grow
alpha = 5  # coefficient for leverage
beta = 5  # coefficient for sigma

X = df[["leverage", "sigma"]]
z = df["log1_std"]

weights = 1 / np.exp(alpha * X["leverage"] + beta * X["sigma"])

model = Pipeline(
    [
        ("poly", PolynomialFeatures(degree=2)),
        ("linear", LinearRegression(fit_intercept=False)),
    ]
)

# fit with WLS weights
model.fit(X, z, linear__sample_weight=weights)

df["log1_std_fitted_wls"] = model.predict(X)

# %%
mean_squared_error(z, df["log1_std_fitted_wls"])
# Out:
# 1.2018629776835841e-06

# %%
z.var()
# Out:
# np.float64(0.0012909507256444377)

# %%
model.score(X, z)
# Out:
# 0.999068916301665

# %% [markdown]
# quartic regression (without restrictions):

# %%
df = pd.read_csv("output/lev_sigma_std.csv")

# %%
# df has columns ['leverage', 'sigma', 'std']
X = df[["leverage", "sigma"]]
z = df["std"]

model = Pipeline(
    [
        ("poly", PolynomialFeatures(degree=4)),
        ("linear", LinearRegression(fit_intercept=False)),
    ]
)

model.fit(X, z)

df["std_fitted"] = model.predict(X)

# %%
print(f"mse = {mean_squared_error(z,df["std_fitted"])}")
# Out:
# mse = 2.1698581039273e-07

# %%
z.var()
# Out:
# np.float64(0.0014532594566834995)

# %%
model.score(X, z)
# Out:
# 0.9998506753146207

# %% [markdown]
# quartic regression with log(1+x) pre-transformation:

# %%
df = pd.read_csv("output/lev_sigma_std.csv")
df["log1_std"] = np.log(1 + df["std"])

# %%
# df has columns ['leverage', 'sigma', 'std']
X = df[["leverage", "sigma"]]
z = df["log1_std"]

model = Pipeline(
    [
        ("poly", PolynomialFeatures(degree=4)),
        ("linear", LinearRegression(fit_intercept=False)),
    ]
)

model.fit(X, z)

df["log1_std_fitted"] = model.predict(X)

# %%
print(f"mse = {mean_squared_error(z,df["log1_std_fitted"])}")
print(z.var())
print(model.score(X, z))
# Out:
# mse = 1.7945128840507243e-07
# 0.0012909507256444377
# 0.9998609790197538

# %%
# see the coefficients

coefficients = model.named_steps["linear"].coef_
intercept = model.named_steps["linear"].intercept_

feature_names = model.named_steps["poly"].get_feature_names_out()

coef_df = pd.DataFrame({"Feature": feature_names, "Coefficient": coefficients})
print(coef_df)
print(f"Intercept: {intercept}")
# Out:
#                Feature  Coefficient
# 0                    1    -0.000391
# 1             leverage     0.001170
# 2                sigma    -0.145816
# 3           leverage^2    -0.001170
# 4       leverage sigma     0.148743
# 5              sigma^2    -0.001361
# 6           leverage^3     0.000464
# 7     leverage^2 sigma    -0.003369
# 8     leverage sigma^2     0.004245
# 9              sigma^3     0.002775
# 10          leverage^4    -0.000063
# 11    leverage^3 sigma     0.000367
# 12  leverage^2 sigma^2    -0.004738
# 13    leverage sigma^3     0.004280
# 14             sigma^4    -0.006068
# Intercept: 0.0

# %%
# compare on original scale

df["std_fitted"] = np.exp(df["log1_std_fitted"]) - 1

print("original-scale mse = ", mean_squared_error(df["std"], df["std_fitted"]))

r2_original_scale = (
    1
    - ((df["std"] - df["std_fitted"]) ** 2).sum()
    / ((df["std"] - df["std"].mean()) ** 2).sum()
)
print("original-scale R^2 = ", r2_original_scale)
# Out:
# original-scale mse =  2.170237364679882e-07
# original-scale R^2 =  0.9998506492147607

# %% [markdown]
# Now create a consolidated procedure for outputting mse and r2:

# %%
dfs = [pd.read_csv(f"output/lev_sigma_std_{i}.csv") for i in range(1, 6)]

# %%
# General function: input is degree of polynomial,
# and boolean whether to preprocess with log(1+x) or not
# Include graphing of residuals and original


def model_evaluate(df, degree=2, take_log=False, plot=False):

    def plot_surface():

        df_copy = df.copy()
        df_copy["z"] = z
        df_copy["z_hat"] = z_hat

        # reshape into matrix form
        pivot_org = df_copy.pivot(index="sigma", columns="leverage", values="z")
        pivot_hat = df_copy.pivot(index="sigma", columns="leverage", values="z_hat")

        X = pivot.columns.values  # leverage values
        Y = pivot.index.values  # sigma values
        Z_org = pivot_org.values  # original std values
        Z_hat = pivot_hat.values  # fitted std values

        X, Y = np.meshgrid(X, Y)

        fig = plt.figure(figsize=(8, 6))
        plt.tight_layout()
        ax = fig.add_subplot(projection="3d")

        ax.plot_surface(X, Y, Z_org, alpha=0.6)
        ax.plot_wireframe(X, Y, Z_hat)

        ax.set_xlabel("leverage")
        ax.set_ylabel("sigma")
        ax.set_zlabel("std")
        plt.title("mesh grid is the fitted values")

        plt.show()

    X = df[["leverage", "sigma"]]

    z = df["std"]
    # transformer.transform(z)
    z = np.log(1 + df["std"]) if take_log else df["std"]

    model = Pipeline(
        [
            ("poly", PolynomialFeatures(degree=degree)),
            ("linear", LinearRegression(fit_intercept=False)),
        ]
    )

    model.fit(X, z)

    z_hat = model.predict(X)

    if take_log:
        z_hat = np.exp(z_hat) - 1

    mse = mean_squared_error(df["std"], z_hat)
    print("original-scale" if take_log else "", "mse = ", mse)

    r2 = (
        1
        - ((df["std"] - z_hat) ** 2).sum() / ((df["std"] - df["std"].mean()) ** 2).sum()
    )

    print("original-scale" if take_log else "", "R^2 = ", r2)

    if plot:
        plot_surface()

    return mse, r2

# %%
df = pd.read_csv("output/lev_sigma_std_1.csv")

# %%
model_evaluate(df, degree=4, take_log=False, plot=True)
# Out:
#  mse =  2.1929237080429666e-07
#  R^2 =  0.9998490731159387
# (2.1929237080429666e-07, np.float64(0.9998490731159387))
