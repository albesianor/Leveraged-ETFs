# %%
import pandas as pd
import numpy as np
from utils import lev_sigma_duration_mean_std

# %%
"""
def lev_sigma_mean_std(
    mu=0,
    sigmas=np.linspace(0.01, 0.6, 100),
    T=5,
    freq=1,
    n_paths=10_000,
    leverages=np.linspace(1.01, 3, 100),
):
"""
# Out:
# '\ndef lev_sigma_mean_std(\n    mu=0,\n    sigmas=np.linspace(0.01, 0.6, 100),\n    T=5,\n    freq=1,\n    n_paths=10_000,\n    leverages=np.linspace(1.01, 3, 100),\n):\n'

# %%
df = lev_sigma_duration_mean_std()
df.to_csv("output/train/df_train_0.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = lev_sigma_duration_mean_std()
#       2 df.to_csv("output/train/df_train_0.csv")
#
# File ~/Desktop/leveraged etf/Leveraged-ETFs/utils.py:192, in lev_sigma_duration_mean_std(mu, sigmas, durations, n_paths, leverages)
#     175 """
#     176 Simulate P&L mean and std of n_paths of GBM portfolios of 1 long leveraged ETF and 1 short underlying,
#     177 with volatility ranging in sigmas, leverage ranging in leverages, and hold duration ranging in durations.
#    (...)
#     187 Pandas dataframe with columns leverage, sigma, mean of P&L, std of P&L
#     188 """
#     190 leverage, sigma, duration = np.meshgrid(leverages, sigmas, durations, indexing="ij")
# --> 192 mean, std = np.vectorize(simulate_gbm)(
#     193     S0=1,
#     194     mu=mu,
#     195     sigma=sigma,
#     196     T=duration,
# ...

# %%
df = lev_sigma_duration_mean_std(
    sigmas=np.linspace(0.01, 0.6, 200), leverages=np.linspace(1.01, 3, 170)
)
df.to_csv(f"output/train/df_train_1.csv")

# %%
df = lev_sigma_duration_mean_std(sigmas=np.linspace(0.01, 0.6, 190))
df.to_csv(f"output/train/df_train_2.csv")

# %%
df = lev_sigma_duration_mean_std(leverages=np.linspace(1.01, 3, 230))
df.to_csv(f"output/train/df_train_3.csv")

# %%
df = lev_sigma_duration_mean_std(
    sigmas=np.linspace(0.01, 0.6, 267), leverages=np.linspace(1.01, 3, 127)
)
df.to_csv(f"output/train/df_train_4.csv")

# %%
df = lev_sigma_duration_mean_std(
    sigmas=np.linspace(0.01, 0.6, 195), leverages=np.linspace(1.01, 3, 281)
)
df.to_csv(f"output/train/df_train_5.csv")

# %%
df = lev_sigma_duration_mean_std(
    sigmas=np.linspace(0.01, 0.6, 199), leverages=np.linspace(1.01, 3, 97)
)
df.to_csv(f"output/train/df_train_6.csv")

# %%
df = lev_sigma_duration_mean_std(
    sigmas=np.linspace(0.01, 0.6, 173), leverages=np.linspace(1.01, 3, 252)
)
df.to_csv(f"output/train/df_train_7.csv")

# %%
df = lev_sigma_duration_mean_std(
    sigmas=np.linspace(0.01, 0.6, 220), leverages=np.linspace(1.01, 3, 163)
)
df.to_csv(f"output/train/df_train_8.csv")

# %%
df = lev_sigma_duration_mean_std(
    sigmas=np.linspace(0.01, 0.6, 421), leverages=np.linspace(1.01, 3, 83)
)
df.to_csv(f"output/train/df_train_9.csv")

# %%
df = lev_sigma_duration_mean_std(
    sigmas=np.linspace(0.01, 0.6, 113), leverages=np.linspace(1.01, 3, 257)
)
df.to_csv(f"output/train/df_train_10.csv")

# %%
df = lev_sigma_duration_mean_std(sigmas=np.linspace(0.01, 0.6, 191))
df.to_csv(f"output/test/df_test_1.csv")

# %%
df = lev_sigma_duration_mean_std(leverages=np.linspace(1.01, 3, 227))
df.to_csv(f"output/test/df_test_2.csv")

# %%
df = lev_sigma_duration_mean_std(
    sigmas=np.linspace(0.01, 0.6, 347), leverages=np.linspace(1.01, 3, 61)
)
df.to_csv(f"output/test/df_test_3.csv")

# %%
df = lev_sigma_duration_mean_std(
    sigmas=np.linspace(0.01, 0.6, 175), leverages=np.linspace(1.01, 3, 249)
)
df.to_csv(f"output/test/df_test_4.csv")

# %%
df = lev_sigma_duration_mean_std(
    sigmas=np.linspace(0.01, 0.6, 269), leverages=np.linspace(1.01, 3, 141)
)
df.to_csv(f"output/test/df_test_5.csv")

# %%
#df = lev_sigma_duration_mean_std(
#    sigmas=np.linspace(0.01, 0.6, 250),
#    n_paths=50_000,
#    leverages=np.linspace(1.01, 3, 250),
#)
#df.to_csv(f"output/train/df_large_train.csv")
