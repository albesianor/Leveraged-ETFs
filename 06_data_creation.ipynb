# %%
import pandas as pd
import numpy as np
from utils import lev_sigma_mean_std

# %%
"""
def lev_sigma_mean_std(
    mu=0,
    sigmas=np.linspace(0.01, 0.4, 100),
    T=5,
    freq=1,
    n_paths=10_000,
    leverages=np.linspace(1.01, 3, 100),
):
"""

# %%
df = lev_sigma_mean_std()
df.to_csv("output/train/df_train_0.csv")
# Out:
# /Users/aleksandarmilivojevic/Desktop/leveraged etf/Leveraged-ETFs/utils.py:40: RuntimeWarning: invalid value encountered in log
#   np.cumsum(np.log((np.exp(drift + diffusion) - 1) * leverage + 1), axis=1)

# %%
df = lev_sigma_mean_std(sigmas=np.linspace(0.01, 0.7, 200), leverages=np.linspace(1.01, 5, 170))
df.to_csv(f"output/train/df_train_1.csv")
# Out:
# /Users/aleksandarmilivojevic/Desktop/leveraged etf/Leveraged-ETFs/utils.py:40: RuntimeWarning: invalid value encountered in log
#   np.cumsum(np.log((np.exp(drift + diffusion) - 1) * leverage + 1), axis=1)

# %%
df = lev_sigma_mean_std(sigmas=np.linspace(0.01, 0.55, 190))
df.to_csv(f"output/train/df_train_2.csv")
# Out:
# /Users/aleksandarmilivojevic/Desktop/leveraged etf/Leveraged-ETFs/utils.py:40: RuntimeWarning: invalid value encountered in log
#   np.cumsum(np.log((np.exp(drift + diffusion) - 1) * leverage + 1), axis=1)

# %%
df = lev_sigma_mean_std(leverages=np.linspace(1.01, 4.8, 230))
df.to_csv(f"output/train/df_train_3.csv")
# Out:
# /Users/aleksandarmilivojevic/Desktop/leveraged etf/Leveraged-ETFs/utils.py:40: RuntimeWarning: invalid value encountered in log
#   np.cumsum(np.log((np.exp(drift + diffusion) - 1) * leverage + 1), axis=1)

# %%
df = lev_sigma_mean_std(sigmas=np.linspace(0.01, 0.48, 267), leverages=np.linspace(1.01, 5, 127))
df.to_csv(f"output/train/df_train_4.csv")
# Out:
# /Users/aleksandarmilivojevic/Desktop/leveraged etf/Leveraged-ETFs/utils.py:40: RuntimeWarning: invalid value encountered in log
#   np.cumsum(np.log((np.exp(drift + diffusion) - 1) * leverage + 1), axis=1)

# %%
df = lev_sigma_mean_std(sigmas=np.linspace(0.01, 0.7, 195), leverages=np.linspace(1.01, 4.6, 281))
df.to_csv(f"output/train/df_train_5.csv")
# Out:
# /Users/aleksandarmilivojevic/Desktop/leveraged etf/Leveraged-ETFs/utils.py:40: RuntimeWarning: invalid value encountered in log
#   np.cumsum(np.log((np.exp(drift + diffusion) - 1) * leverage + 1), axis=1)

# %%
df = lev_sigma_mean_std(sigmas=np.linspace(0.01, 0.66, 199), leverages=np.linspace(1.01, 3.25, 97))
df.to_csv(f"output/train/df_train_6.csv")
# Out:
# /Users/aleksandarmilivojevic/Desktop/leveraged etf/Leveraged-ETFs/utils.py:40: RuntimeWarning: invalid value encountered in log
#   np.cumsum(np.log((np.exp(drift + diffusion) - 1) * leverage + 1), axis=1)

# %%
df = lev_sigma_mean_std(sigmas=np.linspace(0.01, 0.52, 173), leverages=np.linspace(1.01, 5, 252))
df.to_csv(f"output/train/df_train_7.csv")
# Out:
# /Users/aleksandarmilivojevic/Desktop/leveraged etf/Leveraged-ETFs/utils.py:40: RuntimeWarning: invalid value encountered in log
#   np.cumsum(np.log((np.exp(drift + diffusion) - 1) * leverage + 1), axis=1)

# %%
df = lev_sigma_mean_std(sigmas=np.linspace(0.01, 0.7, 220), leverages=np.linspace(1.01, 2.75, 163))
df.to_csv(f"output/train/df_train_8.csv")
# Out:
# /Users/aleksandarmilivojevic/Desktop/leveraged etf/Leveraged-ETFs/utils.py:40: RuntimeWarning: invalid value encountered in log
#   np.cumsum(np.log((np.exp(drift + diffusion) - 1) * leverage + 1), axis=1)

# %%
df = lev_sigma_mean_std(sigmas=np.linspace(0.01, 0.41, 421), leverages=np.linspace(1.01, 4.9, 83))
df.to_csv(f"output/train/df_train_9.csv")
# Out:
# /Users/aleksandarmilivojevic/Desktop/leveraged etf/Leveraged-ETFs/utils.py:40: RuntimeWarning: invalid value encountered in log
#   np.cumsum(np.log((np.exp(drift + diffusion) - 1) * leverage + 1), axis=1)

# %%
df = lev_sigma_mean_std(sigmas=np.linspace(0.01, 0.58, 113), leverages=np.linspace(1.01, 3.6, 257))
df.to_csv(f"output/train/df_train_10.csv")
# Out:
# /Users/aleksandarmilivojevic/Desktop/leveraged etf/Leveraged-ETFs/utils.py:40: RuntimeWarning: invalid value encountered in log
#   np.cumsum(np.log((np.exp(drift + diffusion) - 1) * leverage + 1), axis=1)

# %%
df = lev_sigma_mean_std(sigmas=np.linspace(0.01, 0.7, 191))
df.to_csv(f"output/test/df_test_1.csv")
# Out:
# /Users/aleksandarmilivojevic/Desktop/leveraged etf/Leveraged-ETFs/utils.py:40: RuntimeWarning: invalid value encountered in log
#   np.cumsum(np.log((np.exp(drift + diffusion) - 1) * leverage + 1), axis=1)

# %%
df = lev_sigma_mean_std(leverages=np.linspace(1.01, 5, 227))
df.to_csv(f"output/test/df_test_2.csv")
# Out:
# /Users/aleksandarmilivojevic/Desktop/leveraged etf/Leveraged-ETFs/utils.py:40: RuntimeWarning: invalid value encountered in log
#   np.cumsum(np.log((np.exp(drift + diffusion) - 1) * leverage + 1), axis=1)

# %%
df = lev_sigma_mean_std(sigmas=np.linspace(0.01, 0.63, 347), leverages=np.linspace(1.01, 4.4, 61))
df.to_csv(f"output/test/df_test_3.csv")
# Out:
# /Users/aleksandarmilivojevic/Desktop/leveraged etf/Leveraged-ETFs/utils.py:40: RuntimeWarning: invalid value encountered in log
#   np.cumsum(np.log((np.exp(drift + diffusion) - 1) * leverage + 1), axis=1)

# %%
df = lev_sigma_mean_std(sigmas=np.linspace(0.01, 0.7, 175), leverages=np.linspace(1.01, 5, 249))
df.to_csv(f"output/test/df_test_4.csv")
# Out:
# /Users/aleksandarmilivojevic/Desktop/leveraged etf/Leveraged-ETFs/utils.py:40: RuntimeWarning: invalid value encountered in log
#   np.cumsum(np.log((np.exp(drift + diffusion) - 1) * leverage + 1), axis=1)

# %%
df = lev_sigma_mean_std(sigmas=np.linspace(0.01, 0.5, 269), leverages=np.linspace(1.01, 3.95, 141))
df.to_csv(f"output/test/df_test_5.csv")
# Out:
# /Users/aleksandarmilivojevic/Desktop/leveraged etf/Leveraged-ETFs/utils.py:40: RuntimeWarning: invalid value encountered in log
#   np.cumsum(np.log((np.exp(drift + diffusion) - 1) * leverage + 1), axis=1)

# %%
df = lev_sigma_mean_std(sigmas=np.linspace(0.01, 0.4, 250), n_paths=50_000, leverages=np.linspace(1.01, 3, 250))
df.to_csv(f"output/train/df_large_train.csv")
# Out:
# /Users/aleksandarmilivojevic/Desktop/leveraged etf/Leveraged-ETFs/utils.py:40: RuntimeWarning: invalid value encountered in log
#   np.cumsum(np.log((np.exp(drift + diffusion) - 1) * leverage + 1), axis=1)
